# %%
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
import datetime as dt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Read in the Pre-Cleaned Data

# %%
data = pd.read_csv("cleaned_data.csv")

# %%
data.head()
# Out:
#    acc_open_past_24mths addr_state  annual_inc  avg_cur_bal    bc_util  \
# 0                   3.0         AZ     24000.0       7516.0  61.644117
# 1                   4.0         GA     30000.0       7516.0  61.644117
# 2                   4.0         IL     12252.0       7516.0  61.644117
# 3                   4.0         CA     49200.0       7516.0  61.644117
# 4                   4.0         OR     80000.0       7516.0  61.644117
#
#    collection_recovery_fee  delinq_2yrs    dti earliest_cr_line emp_length  \
# 0                     0.00          0.0  27.65       1985-01-01  10+ years
# 1                     1.11          0.0   1.00       1999-04-01   < 1 year
# 2                     0.00          0.0   8.72       2001-11-01  10+ years
# 3                     0.00          0.0  20.00       1996-02-01  10+ years
# 4                     0.00          0.0  17.94       1996-01-01     1 year
#
#           ...          total_acc  total_bal_ex_mort total_bc_limit  \
# 0         ...                9.0            36748.0        14500.0
# 1         ...                4.0            36748.0        14500.0
# 2         ...               10.0            36748.0        14500.0
# 3         ...               37.0            36748.0        14500.0
# 4         ...               38.0            36748.0        14500.0
#
#   total_il_high_credit_limit total_pymnt  total_rec_int  total_rec_late_fee  \
# 0                    30791.0     5863.16         863.16                0.00
# 1                    30791.0     1014.53         435.17                0.00
# 2                    30791.0     3005.67         605.67                0.00
# 3                    30791.0    12231.89        2214.92               16.97
# 4                    30791.0     4066.91        1066.91                0.00
#
#    total_rec_prncp total_rev_hi_lim verification_status
# 0          5000.00          23400.0            Verified
# 1           456.46          23400.0     Source Verified
# 2          2400.00          23400.0        Not Verified
# 3         10000.00          23400.0     Source Verified
# 4          3000.00          23400.0     Source Verified
#
# [5 rows x 56 columns]

# %%
data.shape
# Out:
# (747488, 56)

# %% [markdown]
# # Clean the data and get train test split

# %%
emp_dict = {'1 year': 1, '2 years': 2, '3 years': 3, '4 years': 4, '5 years': 5, '6 years': 6, '7 years': 7, 
            '8 years': 8, '9 years': 9, '< 1 year': 0, '10+ years': 10, 'n/a': None}
data['emp_length'] = data['emp_length'].map(emp_dict)
# data = data.dropna() # this does nothing, as far as I can tell
y = data['loan_status']
x = data.drop('loan_status', axis = 1)
x = pd.get_dummies(x, columns = ['verification_status', 'initial_list_status', 'grade', 'home_ownership'])
x['earliest_cr_line'] = pd.to_datetime(x['earliest_cr_line']).map(dt.datetime.toordinal)
# x['earliest_cr_line'] = x['earliest_cr_line']
x['issue_d'] = pd.to_datetime(x['issue_d']).map(dt.datetime.toordinal)
# x['issue_d'] = x['issue_d'].map(dt.datetime.toordinal)
x['last_credit_pull_d'] = pd.to_datetime(x['last_credit_pull_d']).map(dt.datetime.toordinal)
# x['last_credit_pull_d'] = x['last_credit_pull_d'].map(dt.datetime.toordinal)
x['last_pymnt_d'] = pd.to_datetime(x['last_pymnt_d']).map(dt.datetime.toordinal)
# x['last_pymnt_d'] = x['last_pymnt_d'].map(dt.datetime.toordinal)
le = LabelEncoder()
x['addr_state'] = le.fit_transform(x['addr_state'])
x['purpose'] = le.fit_transform(x['purpose'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape, x_test.shape
# Out:
# ((523241, 69), (224247, 69))

# %% [markdown]
# # Predict on a Decision Tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
y_pred = clf.predict(x_test)
sum(y_pred == y_test)/len(y_pred)
# Out:
# 0.9965707456510009

# %%
n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold
n_nodes, children_left, children_right, feature, threshold
# Out:
# (2569,
#  array([ 1,  2,  3, ..., -1, -1, -1], dtype=int64),
#  array([2568,  209,  208, ...,   -1,   -1,   -1], dtype=int64),
#  array([36, 49, 10, ..., -2, -2, -2], dtype=int64),
#  array([  4.99999989e-03,   2.99997510e+03,   2.98750000e+03, ...,
#          -2.00000000e+00,  -2.00000000e+00,  -2.00000000e+00]))

# %%
clf.decision_path(x_test)
# Out:
# <224247x2569 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3125366 stored elements in Compressed Sparse Row format>

# %%
n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, -1)]
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1
    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True

print("The binary tree structure has %s nodes and has "
      "the following tree structure:"
      % n_nodes)
for i in range(n_nodes):
    if is_leaves[i]:
        print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
    else:
        print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
              "node %s."
              % (node_depth[i] * "\t",
                 i,
                 children_left[i],
                 feature[i],
                 threshold[i],
                 children_right[i],
                 ))
print()

node_indicator = clf.decision_path(x_test)
leave_id = clf.apply(x_test)

sample_id = 0
node_index = node_indicator.indices[node_indicator.indptr[sample_id]:
                                    node_indicator.indptr[sample_id + 1]]

print('Rules used to predict sample %s: ' % sample_id)
for node_id in node_index:
    if leave_id[sample_id] != node_id:
        continue

    if (x_test[sample_id, feature[node_id]] <= threshold[node_id]):
        threshold_sign = "<="
    else:
        threshold_sign = ">"

    print("decision id node %s : (x_test[%s, %s] (= %s) %s %s)"
          % (node_id,
             sample_id,
             feature[node_id],
             x_test[sample_id, feature[node_id]],
             threshold_sign,
             threshold[node_id]))

sample_ids = [0, 1]
common_nodes = (node_indicator.toarray()[sample_ids].sum(axis=0) ==
                len(sample_ids))

common_node_id = np.arange(n_nodes)[common_nodes]

print("\nThe following samples %s share the node %s in the tree"
      % (sample_ids, common_node_id))
print("It is %s %% of all nodes." % (100 * len(common_node_id) / n_nodes,))
# Out:
# The binary tree structure has 2569 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 36] <= 0.00499999988824 else to node 2568.
# 	node=1 test node: go to node 2 if X[:, 49] <= 2999.97509766 else to node 209.
# 		node=2 test node: go to node 3 if X[:, 10] <= 2987.5 else to node 208.
# 			node=3 test node: go to node 4 if X[:, 49] <= 999.929992676 else to node 7.
# 				node=4 test node: go to node 5 if X[:, 19] <= 975.0 else to node 6.
# 					node=5 leaf node.
# 					node=6 leaf node.
# 				node=7 test node: go to node 8 if X[:, 17] <= 238.644989014 else to node 157.
# 					node=8 test node: go to node 9 if X[:, 15] <= 735553.0 else to node 106.
# 						node=9 test node: go to node 10 if X[:, 15] <= 735218.5 else to node 39.
# 							node=10 test node: go to node 11 if X[:, 25] <= 19.5 else to node 36.
# 								node=11 test node: go to node 12 if X[:, 24] <= 26.5 else to node 33.
# 									node=12 test node: go to node 13 if X[:, 54] <= 0.5 else to node 28.
# 										node=13 test node: go to node 14 if X[:, 18] <= 735826.5 else to node 19.
# 											node=14 test node: go to node 15 if X[:, 13] <= 87.1399993896 else to node 16.
# 												node=15 leaf node.
# 												node=16 test node: go to node 17 if X[:, 28] <= 5.5 else to node 18.
# 													node=17 leaf node.
# 													node=18 leaf node.
# 											node=19 test node: go to node 20 if X[:, 8] <= 732965.5 else to node 25.
# 												node=20 test node: go to node 21 if X[:, 29] <= 4.5 else to node 22.
# 													node=21 leaf node.
# 													node=22 test node: go to node 23 if X[:, 2] <= 34256.0 else to node 24.
# 														node=23 leaf node.
# 														node=24 leaf node.
# 												node=25 test node: go to node 26 if X[:, 50] <= 15050.0 else to node 27.
# 													node=26 leaf node.
# 													node=27 leaf node.
# 										node=28 test node: go to node 29 if X[:, 47] <= 1083.68505859 else to node 30.
# 											node=29 leaf node.
# 											node=30 test node: go to node 31 if X[:, 58] <= 0.5 else to node 32.
# 												node=31 leaf node.
# 												node=32 leaf node.
# 									node=33 test node: go to node 34 if X[:, 37] <= 781.0 else to node 35.
# 										node=34 leaf node.
# 										node=35 leaf node.
# 								node=36 test node: go to node 37 if X[:, 19] <= 1600.0 else to node 38.
# 									node=37 leaf node.
# 									node=38 leaf node.
# 							node=39 test node: go to node 40 if X[:, 18] <= 736314.5 else to node 63.
# 								node=40 test node: go to node 41 if X[:, 47] <= 447.970001221 else to node 50.
# 									node=41 test node: go to node 42 if X[:, 47] <= 287.005004883 else to node 45.
# 										node=42 test node: go to node 43 if X[:, 12] <= 5.5 else to node 44.
# 											node=43 leaf node.
# 											node=44 leaf node.
# 										node=45 test node: go to node 46 if X[:, 46] <= 1779.72497559 else to node 49.
# 											node=46 test node: go to node 47 if X[:, 10] <= 1400.0 else to node 48.
# 												node=47 leaf node.
# 												node=48 leaf node.
# 											node=49 leaf node.
# 									node=50 test node: go to node 51 if X[:, 49] <= 1998.07495117 else to node 56.
# 										node=51 test node: go to node 52 if X[:, 19] <= 1900.0 else to node 55.
# 											node=52 test node: go to node 53 if X[:, 25] <= 14.0 else to node 54.
# 												node=53 leaf node.
# 												node=54 leaf node.
# 											node=55 leaf node.
# 										node=56 test node: go to node 57 if X[:, 31] <= 80.0999984741 else to node 58.
# 											node=57 leaf node.
# 											node=58 test node: go to node 59 if X[:, 38] <= 0.160499989986 else to node 62.
# 												node=59 test node: go to node 60 if X[:, 49] <= 2180.41992188 else to node 61.
# 													node=60 leaf node.
# 													node=61 leaf node.
# 												node=62 leaf node.
# 								node=63 test node: go to node 64 if X[:, 23] <= 38.0 else to node 105.
# 									node=64 test node: go to node 65 if X[:, 18] <= 736496.0 else to node 100.
# 										node=65 test node: go to node 66 if X[:, 15] <= 735430.5 else to node 91.
# 											node=66 test node: go to node 67 if X[:, 15] <= 735400.0 else to node 86.
# 												node=67 test node: go to node 68 if X[:, 7] <= 24.1149997711 else to node 73.
# 													node=68 test node: go to node 69 if X[:, 23] <= 16.5 else to node 70.
# 														node=69 leaf node.
# 														node=70 test node: go to node 71 if X[:, 30] <= 6.5 else to node 72.
# 															node=71 leaf node.
# 															node=72 leaf node.
# 													node=73 test node: go to node 74 if X[:, 7] <= 24.1899986267 else to node 75.
# 														node=74 leaf node.
# 														node=75 test node: go to node 76 if X[:, 38] <= 0.146500006318 else to node 79.
# 															node=76 test node: go to node 77 if X[:, 21] <= 2.5 else to node 78.
# 																node=77 leaf node.
# 																node=78 leaf node.
# 															node=79 test node: go to node 80 if X[:, 4] <= 93.6999969482 else to node 81.
# 																node=80 leaf node.
# 																node=81 test node: go to node 82 if X[:, 49] <= 2642.0949707 else to node 85.
# 																	node=82 test node: go to node 83 if X[:, 12] <= 2.0 else to node 84.
# 																		node=83 leaf node.
# 																		node=84 leaf node.
# 																	node=85 leaf node.
# 												node=86 test node: go to node 87 if X[:, 33] <= 0.5 else to node 88.
# 													node=87 leaf node.
# 													node=88 test node: go to node 89 if X[:, 7] <= 24.8250007629 else to node 90.
# 														node=89 leaf node.
# 														node=90 leaf node.
# 											node=91 test node: go to node 92 if X[:, 47] <= 356.554992676 else to node 93.
# 												node=92 leaf node.
# 												node=93 test node: go to node 94 if X[:, 17] <= 107.270004272 else to node 99.
# 													node=94 test node: go to node 95 if X[:, 17] <= 51.6199989319 else to node 96.
# 														node=95 leaf node.
# 														node=96 test node: go to node 97 if X[:, 13] <= 102.489997864 else to node 98.
# 															node=97 leaf node.
# 															node=98 leaf node.
# 													node=99 leaf node.
# 										node=100 test node: go to node 101 if X[:, 24] <= 21.5 else to node 102.
# 											node=101 leaf node.
# 											node=102 test node: go to node 103 if X[:, 45] <= 14783.0 else to node 104.
# 												node=103 leaf node.
# 												node=104 leaf node.
# 									node=105 leaf node.
# 						node=106 test node: go to node 107 if X[:, 47] <= 334.549987793 else to node 142.
# 							node=107 test node: go to node 108 if X[:, 47] <= 259.304992676 else to node 133.
# 								node=108 test node: go to node 109 if X[:, 13] <= 112.375 else to node 132.
# 									node=109 test node: go to node 110 if X[:, 1] <= 1.5 else to node 113.
# 										node=110 test node: go to node 111 if X[:, 20] <= 0.5 else to node 112.
# 											node=111 leaf node.
# 											node=112 leaf node.
# 										node=113 test node: go to node 114 if X[:, 31] <= 64.3000030518 else to node 117.
# 											node=114 test node: go to node 115 if X[:, 20] <= 1.0 else to node 116.
# 												node=115 leaf node.
# 												node=116 leaf node.
# 											node=117 test node: go to node 118 if X[:, 23] <= 19.5 else to node 129.
# 												node=118 test node: go to node 119 if X[:, 8] <= 732508.5 else to node 120.
# 													node=119 leaf node.
# 													node=120 test node: go to node 121 if X[:, 8] <= 732539.5 else to node 124.
# 														node=121 test node: go to node 122 if X[:, 1] <= 37.0 else to node 123.
# 															node=122 leaf node.
# 															node=123 leaf node.
# 														node=124 test node: go to node 125 if X[:, 21] <= 4.5 else to node 126.
# 															node=125 leaf node.
# 															node=126 test node: go to node 127 if X[:, 42] <= 14.5 else to node 128.
# 																node=127 leaf node.
# 																node=128 leaf node.
# 												node=129 test node: go to node 130 if X[:, 0] <= 4.0 else to node 131.
# 													node=130 leaf node.
# 													node=131 leaf node.
# 									node=132 leaf node.
# 								node=133 test node: go to node 134 if X[:, 49] <= 1398.22497559 else to node 137.
# 									node=134 test node: go to node 135 if X[:, 14] <= 0.172049999237 else to node 136.
# 										node=135 leaf node.
# 										node=136 leaf node.
# 									node=137 test node: go to node 138 if X[:, 14] <= 0.0842500030994 else to node 141.
# 										node=138 test node: go to node 139 if X[:, 34] <= 0.5 else to node 140.
# 											node=139 leaf node.
# 											node=140 leaf node.
# 										node=141 leaf node.
# 							node=142 test node: go to node 143 if X[:, 49] <= 1938.02001953 else to node 150.
# 								node=143 test node: go to node 144 if X[:, 13] <= 55.5900001526 else to node 147.
# 									node=144 test node: go to node 145 if X[:, 41] <= 36231.5 else to node 146.
# 										node=145 leaf node.
# 										node=146 leaf node.
# 									node=147 test node: go to node 148 if X[:, 17] <= 52.4599990845 else to node 149.
# 										node=148 leaf node.
# 										node=149 leaf node.
# 								node=150 test node: go to node 151 if X[:, 8] <= 720912.5 else to node 152.
# 									node=151 leaf node.
# 									node=152 test node: go to node 153 if X[:, 25] <= 2.5 else to node 156.
# 										node=153 test node: go to node 154 if X[:, 10] <= 2400.0 else to node 155.
# 											node=154 leaf node.
# 											node=155 leaf node.
# 										node=156 leaf node.
# 					node=157 test node: go to node 158 if X[:, 48] <= 52.5 else to node 205.
# 						node=158 test node: go to node 159 if X[:, 48] <= 7.5 else to node 186.
# 							node=159 test node: go to node 160 if X[:, 17] <= 283.345001221 else to node 167.
# 								node=160 test node: go to node 161 if X[:, 17] <= 282.934997559 else to node 166.
# 									node=161 test node: go to node 162 if X[:, 44] <= 48850.0 else to node 163.
# 										node=162 leaf node.
# 										node=163 test node: go to node 164 if X[:, 26] <= 9.5 else to node 165.
# 											node=164 leaf node.
# 											node=165 leaf node.
# 									node=166 leaf node.
# 								node=167 test node: go to node 168 if X[:, 2] <= 12126.0 else to node 173.
# 									node=168 test node: go to node 169 if X[:, 50] <= 65500.0 else to node 170.
# 										node=169 leaf node.
# 										node=170 test node: go to node 171 if X[:, 32] <= 62.5 else to node 172.
# 											node=171 leaf node.
# 											node=172 leaf node.
# 									node=173 test node: go to node 174 if X[:, 24] <= 0.5 else to node 179.
# 										node=174 test node: go to node 175 if X[:, 2] <= 94000.0 else to node 176.
# 											node=175 leaf node.
# 											node=176 test node: go to node 177 if X[:, 38] <= 0.465499997139 else to node 178.
# 												node=177 leaf node.
# 												node=178 leaf node.
# 										node=179 test node: go to node 180 if X[:, 23] <= 1.5 else to node 185.
# 											node=180 test node: go to node 181 if X[:, 25] <= 9.5 else to node 182.
# 												node=181 leaf node.
# 												node=182 test node: go to node 183 if X[:, 52] <= 0.5 else to node 184.
# 													node=183 leaf node.
# 													node=184 leaf node.
# 											node=185 leaf node.
# 							node=186 test node: go to node 187 if X[:, 50] <= 129650.0 else to node 204.
# 								node=187 test node: go to node 188 if X[:, 29] <= 9.0 else to node 203.
# 									node=188 test node: go to node 189 if X[:, 26] <= 2.5 else to node 192.
# 										node=189 test node: go to node 190 if X[:, 27] <= 1.5 else to node 191.
# 											node=190 leaf node.
# 											node=191 leaf node.
# 										node=192 test node: go to node 193 if X[:, 24] <= 1.5 else to node 198.
# 											node=193 test node: go to node 194 if X[:, 37] <= 5619.0 else to node 195.
# 												node=194 leaf node.
# 												node=195 test node: go to node 196 if X[:, 32] <= 41.6500015259 else to node 197.
# 													node=196 leaf node.
# 													node=197 leaf node.
# 											node=198 test node: go to node 199 if X[:, 4] <= 101.650001526 else to node 200.
# 												node=199 leaf node.
# 												node=200 test node: go to node 201 if X[:, 43] <= 36259.0 else to node 202.
# 													node=201 leaf node.
# 													node=202 leaf node.
# 									node=203 leaf node.
# 								node=204 leaf node.
# 						node=205 test node: go to node 206 if X[:, 15] <= 735827.0 else to node 207.
# 							node=206 leaf node.
# 							node=207 leaf node.
# 			node=208 leaf node.
# 		node=209 test node: go to node 210 if X[:, 17] <= 1300.56005859 else to node 2129.
# 			node=210 test node: go to node 211 if X[:, 15] <= 735553.0 else to node 1818.
# 				node=211 test node: go to node 212 if X[:, 39] <= 48.0 else to node 1599.
# 					node=212 test node: go to node 213 if X[:, 15] <= 735249.5 else to node 686.
# 						node=213 test node: go to node 214 if X[:, 55] <= 0.5 else to node 431.
# 							node=214 test node: go to node 215 if X[:, 15] <= 735218.5 else to node 386.
# 								node=215 test node: go to node 216 if X[:, 18] <= 735583.5 else to node 311.
# 									node=216 test node: go to node 217 if X[:, 15] <= 734578.5 else to node 268.
# 										node=217 test node: go to node 218 if X[:, 18] <= 733453.0 else to node 221.
# 											node=218 test node: go to node 219 if X[:, 13] <= 463.475006104 else to node 220.
# 												node=219 leaf node.
# 												node=220 leaf node.
# 											node=221 test node: go to node 222 if X[:, 30] <= 27.5 else to node 263.
# 												node=222 test node: go to node 223 if X[:, 18] <= 733818.0 else to node 228.
# 													node=223 test node: go to node 224 if X[:, 16] <= 736618.5 else to node 225.
# 														node=224 leaf node.
# 														node=225 test node: go to node 226 if X[:, 37] <= 23205.5 else to node 227.
# 															node=226 leaf node.
# 															node=227 leaf node.
# 													node=228 test node: go to node 229 if X[:, 34] <= 0.5 else to node 252.
# 														node=229 test node: go to node 230 if X[:, 15] <= 734487.5 else to node 243.
# 															node=230 test node: go to node 231 if X[:, 14] <= 0.143999993801 else to node 232.
# 																node=231 leaf node.
# 																node=232 test node: go to node 233 if X[:, 18] <= 734365.5 else to node 238.
# 																	node=233 test node: go to node 234 if X[:, 42] <= 35.5 else to node 235.
# 																		node=234 leaf node.
# 																		node=235 test node: go to node 236 if X[:, 46] <= 10122.5996094 else to node 237.
# 																			node=236 leaf node.
# 																			node=237 leaf node.
# 																	node=238 test node: go to node 239 if X[:, 1] <= 46.5 else to node 240.
# 																		node=239 leaf node.
# 																		node=240 test node: go to node 241 if X[:, 15] <= 734457.0 else to node 242.
# 																			node=241 leaf node.
# 																			node=242 leaf node.
# 															node=243 test node: go to node 244 if X[:, 48] <= 7.53798389435 else to node 249.
# 																node=244 test node: go to node 245 if X[:, 17] <= 33.2999992371 else to node 248.
# 																	node=245 test node: go to node 246 if X[:, 17] <= 26.5699996948 else to node 247.
# 																		node=246 leaf node.
# 																		node=247 leaf node.
# 																	node=248 leaf node.
# 																node=249 test node: go to node 250 if X[:, 48] <= 14.9970645905 else to node 251.
# 																	node=250 leaf node.
# 																	node=251 leaf node.
# 														node=252 test node: go to node 253 if X[:, 15] <= 734365.5 else to node 254.
# 															node=253 leaf node.
# 															node=254 test node: go to node 255 if X[:, 35] <= 10.0 else to node 260.
# 																node=255 test node: go to node 256 if X[:, 17] <= 38.7700004578 else to node 259.
# 																	node=256 test node: go to node 257 if X[:, 59] <= 0.5 else to node 258.
# 																		node=257 leaf node.
# 																		node=258 leaf node.
# 																	node=259 leaf node.
# 																node=260 test node: go to node 261 if X[:, 37] <= 7146.5 else to node 262.
# 																	node=261 leaf node.
# 																	node=262 leaf node.
# 												node=263 test node: go to node 264 if X[:, 17] <= 81.0749969482 else to node 267.
# 													node=264 test node: go to node 265 if X[:, 9] <= 9.0 else to node 266.
# 														node=265 leaf node.
# 														node=266 leaf node.
# 													node=267 leaf node.
# 										node=268 test node: go to node 269 if X[:, 47] <= 1738.70507813 else to node 290.
# 											node=269 test node: go to node 270 if X[:, 48] <= 7.49988651276 else to node 287.
# 												node=270 test node: go to node 271 if X[:, 22] <= 12.5 else to node 284.
# 													node=271 test node: go to node 272 if X[:, 7] <= 28.8400001526 else to node 281.
# 														node=272 test node: go to node 273 if X[:, 23] <= 20.5 else to node 278.
# 															node=273 test node: go to node 274 if X[:, 37] <= 25479.5 else to node 275.
# 																node=274 leaf node.
# 																node=275 test node: go to node 276 if X[:, 37] <= 25700.0 else to node 277.
# 																	node=276 leaf node.
# 																	node=277 leaf node.
# 															node=278 test node: go to node 279 if X[:, 8] <= 731169.0 else to node 280.
# 																node=279 leaf node.
# 																node=280 leaf node.
# 														node=281 test node: go to node 282 if X[:, 7] <= 29.0900001526 else to node 283.
# 															node=282 leaf node.
# 															node=283 leaf node.
# 													node=284 test node: go to node 285 if X[:, 40] <= 231788.5 else to node 286.
# 														node=285 leaf node.
# 														node=286 leaf node.
# 												node=287 test node: go to node 288 if X[:, 37] <= 9152.5 else to node 289.
# 													node=288 leaf node.
# 													node=289 leaf node.
# 											node=290 test node: go to node 291 if X[:, 49] <= 7952.58496094 else to node 292.
# 												node=291 leaf node.
# 												node=292 test node: go to node 293 if X[:, 34] <= 0.5 else to node 308.
# 													node=293 test node: go to node 294 if X[:, 48] <= 55.2288589478 else to node 307.
# 														node=294 test node: go to node 295 if X[:, 47] <= 6363.88476563 else to node 304.
# 															node=295 test node: go to node 296 if X[:, 49] <= 8395.42480469 else to node 299.
# 																node=296 test node: go to node 297 if X[:, 58] <= 0.5 else to node 298.
# 																	node=297 leaf node.
# 																	node=298 leaf node.
# 																node=299 test node: go to node 300 if X[:, 42] <= 55.0 else to node 301.
# 																	node=300 leaf node.
# 																	node=301 test node: go to node 302 if X[:, 28] <= 16.5 else to node 303.
# 																		node=302 leaf node.
# 																		node=303 leaf node.
# 															node=304 test node: go to node 305 if X[:, 46] <= 27315.9042969 else to node 306.
# 																node=305 leaf node.
# 																node=306 leaf node.
# 														node=307 leaf node.
# 													node=308 test node: go to node 309 if X[:, 43] <= 48151.5 else to node 310.
# 														node=309 leaf node.
# 														node=310 leaf node.
# 									node=311 test node: go to node 312 if X[:, 4] <= 110.649993896 else to node 383.
# 										node=312 test node: go to node 313 if X[:, 25] <= 21.5 else to node 376.
# 											node=313 test node: go to node 314 if X[:, 15] <= 735157.5 else to node 329.
# 												node=314 test node: go to node 315 if X[:, 49] <= 5245.99023438 else to node 324.
# 													node=315 test node: go to node 316 if X[:, 10] <= 5412.5 else to node 323.
# 														node=316 test node: go to node 317 if X[:, 42] <= 5.5 else to node 322.
# 															node=317 test node: go to node 318 if X[:, 12] <= 2.5 else to node 319.
# 																node=318 leaf node.
# 																node=319 test node: go to node 320 if X[:, 44] <= 7700.0 else to node 321.
# 																	node=320 leaf node.
# 																	node=321 leaf node.
# 															node=322 leaf node.
# 														node=323 leaf node.
# 													node=324 test node: go to node 325 if X[:, 37] <= 1035.0 else to node 328.
# 														node=325 test node: go to node 326 if X[:, 37] <= 1032.5 else to node 327.
# 															node=326 leaf node.
# 															node=327 leaf node.
# 														node=328 leaf node.
# 												node=329 test node: go to node 330 if X[:, 35] <= 11.5 else to node 373.
# 													node=330 test node: go to node 331 if X[:, 21] <= 8.5 else to node 364.
# 														node=331 test node: go to node 332 if X[:, 18] <= 736253.5 else to node 359.
# 															node=332 test node: go to node 333 if X[:, 48] <= 26.3299999237 else to node 356.
# 																node=333 test node: go to node 334 if X[:, 40] <= 578864.0 else to node 353.
# 																	node=334 test node: go to node 335 if X[:, 27] <= 10.5 else to node 350.
# 																		node=335 test node: go to node 336 if X[:, 26] <= 4.5 else to node 341.
# 																			node=336 test node: go to node 337 if X[:, 8] <= 728110.5 else to node 340.
# 																				node=337 test node: go to node 338 if X[:, 43] <= 47410.5 else to node 339.
# 																					node=338 leaf node.
# 																					node=339 leaf node.
# 																				node=340 leaf node.
# 																			node=341 test node: go to node 342 if X[:, 34] <= 0.5 else to node 343.
# 																				node=342 leaf node.
# 																				node=343 test node: go to node 344 if X[:, 21] <= 4.5 else to node 345.
# 																					node=344 leaf node.
# 																					node=345 test node: go to node 346 if X[:, 29] <= 0.5 else to node 349.
# 																						node=346 test node: go to node 347 if X[:, 10] <= 9900.0 else to node 348.
# 																							node=347 leaf node.
# 																							node=348 leaf node.
# 																						node=349 leaf node.
# 																		node=350 test node: go to node 351 if X[:, 26] <= 11.5 else to node 352.
# 																			node=351 leaf node.
# 																			node=352 leaf node.
# 																	node=353 test node: go to node 354 if X[:, 7] <= 20.9049987793 else to node 355.
# 																		node=354 leaf node.
# 																		node=355 leaf node.
# 																node=356 test node: go to node 357 if X[:, 27] <= 4.5 else to node 358.
# 																	node=357 leaf node.
# 																	node=358 leaf node.
# 															node=359 test node: go to node 360 if X[:, 23] <= 21.5 else to node 361.
# 																node=360 leaf node.
# 																node=361 test node: go to node 362 if X[:, 44] <= 7150.0 else to node 363.
# 																	node=362 leaf node.
# 																	node=363 leaf node.
# 														node=364 test node: go to node 365 if X[:, 48] <= 7.5 else to node 370.
# 															node=365 test node: go to node 366 if X[:, 0] <= 11.0 else to node 367.
# 																node=366 leaf node.
# 																node=367 test node: go to node 368 if X[:, 15] <= 735188.0 else to node 369.
# 																	node=368 leaf node.
# 																	node=369 leaf node.
# 															node=370 test node: go to node 371 if X[:, 7] <= 24.0299987793 else to node 372.
# 																node=371 leaf node.
# 																node=372 leaf node.
# 													node=373 test node: go to node 374 if X[:, 2] <= 22900.0 else to node 375.
# 														node=374 leaf node.
# 														node=375 leaf node.
# 											node=376 test node: go to node 377 if X[:, 7] <= 33.1800003052 else to node 382.
# 												node=377 test node: go to node 378 if X[:, 8] <= 731184.5 else to node 379.
# 													node=378 leaf node.
# 													node=379 test node: go to node 380 if X[:, 47] <= 4118.1953125 else to node 381.
# 														node=380 leaf node.
# 														node=381 leaf node.
# 												node=382 leaf node.
# 										node=383 test node: go to node 384 if X[:, 49] <= 16467.5546875 else to node 385.
# 											node=384 leaf node.
# 											node=385 leaf node.
# 								node=386 test node: go to node 387 if X[:, 18] <= 736253.5 else to node 416.
# 									node=387 test node: go to node 388 if X[:, 47] <= 1937.14990234 else to node 401.
# 										node=388 test node: go to node 389 if X[:, 49] <= 4793.24023438 else to node 392.
# 											node=389 test node: go to node 390 if X[:, 11] <= 4650.0 else to node 391.
# 												node=390 leaf node.
# 												node=391 leaf node.
# 											node=392 test node: go to node 393 if X[:, 31] <= 65.5 else to node 396.
# 												node=393 test node: go to node 394 if X[:, 2] <= 82500.0 else to node 395.
# 													node=394 leaf node.
# 													node=395 leaf node.
# 												node=396 test node: go to node 397 if X[:, 4] <= 97.6000061035 else to node 398.
# 													node=397 leaf node.
# 													node=398 test node: go to node 399 if X[:, 33] <= 0.5 else to node 400.
# 														node=399 leaf node.
# 														node=400 leaf node.
# 										node=401 test node: go to node 402 if X[:, 49] <= 11377.8046875 else to node 409.
# 											node=402 test node: go to node 403 if X[:, 13] <= 387.799987793 else to node 408.
# 												node=403 test node: go to node 404 if X[:, 49] <= 7298.6953125 else to node 407.
# 													node=404 test node: go to node 405 if X[:, 14] <= 0.19525000453 else to node 406.
# 														node=405 leaf node.
# 														node=406 leaf node.
# 													node=407 leaf node.
# 												node=408 leaf node.
# 											node=409 test node: go to node 410 if X[:, 17] <= 562.719970703 else to node 411.
# 												node=410 leaf node.
# 												node=411 test node: go to node 412 if X[:, 7] <= 20.9750003815 else to node 415.
# 													node=412 test node: go to node 413 if X[:, 13] <= 579.545043945 else to node 414.
# 														node=413 leaf node.
# 														node=414 leaf node.
# 													node=415 leaf node.
# 									node=416 test node: go to node 417 if X[:, 33] <= 6.5 else to node 428.
# 										node=417 test node: go to node 418 if X[:, 1] <= 48.5 else to node 425.
# 											node=418 test node: go to node 419 if X[:, 14] <= 0.0776000022888 else to node 424.
# 												node=419 test node: go to node 420 if X[:, 18] <= 736314.5 else to node 423.
# 													node=420 test node: go to node 421 if X[:, 42] <= 20.0 else to node 422.
# 														node=421 leaf node.
# 														node=422 leaf node.
# 													node=423 leaf node.
# 												node=424 leaf node.
# 											node=425 test node: go to node 426 if X[:, 12] <= 2.5 else to node 427.
# 												node=426 leaf node.
# 												node=427 leaf node.
# 										node=428 test node: go to node 429 if X[:, 43] <= 36632.0 else to node 430.
# 											node=429 leaf node.
# 											node=430 leaf node.
# 							node=431 test node: go to node 432 if X[:, 18] <= 735795.5 else to node 473.
# 								node=432 test node: go to node 433 if X[:, 49] <= 6992.99511719 else to node 444.
# 									node=433 test node: go to node 434 if X[:, 13] <= 235.574996948 else to node 443.
# 										node=434 test node: go to node 435 if X[:, 47] <= 1593.93505859 else to node 442.
# 											node=435 test node: go to node 436 if X[:, 11] <= 6850.0 else to node 441.
# 												node=436 test node: go to node 437 if X[:, 47] <= 1017.22998047 else to node 438.
# 													node=437 leaf node.
# 													node=438 test node: go to node 439 if X[:, 49] <= 4743.37011719 else to node 440.
# 														node=439 leaf node.
# 														node=440 leaf node.
# 												node=441 leaf node.
# 											node=442 leaf node.
# 										node=443 leaf node.
# 									node=444 test node: go to node 445 if X[:, 47] <= 2611.39501953 else to node 462.
# 										node=445 test node: go to node 446 if X[:, 48] <= 22.4799995422 else to node 461.
# 											node=446 test node: go to node 447 if X[:, 49] <= 7487.20996094 else to node 450.
# 												node=447 test node: go to node 448 if X[:, 19] <= 8400.0 else to node 449.
# 													node=448 leaf node.
# 													node=449 leaf node.
# 												node=450 test node: go to node 451 if X[:, 11] <= 17025.0 else to node 458.
# 													node=451 test node: go to node 452 if X[:, 40] <= 13301.5 else to node 457.
# 														node=452 test node: go to node 453 if X[:, 40] <= 12600.0 else to node 454.
# 															node=453 leaf node.
# 															node=454 test node: go to node 455 if X[:, 58] <= 0.5 else to node 456.
# 																node=455 leaf node.
# 																node=456 leaf node.
# 														node=457 leaf node.
# 													node=458 test node: go to node 459 if X[:, 49] <= 15150.0449219 else to node 460.
# 														node=459 leaf node.
# 														node=460 leaf node.
# 											node=461 leaf node.
# 										node=462 test node: go to node 463 if X[:, 49] <= 14839.1796875 else to node 468.
# 											node=463 test node: go to node 464 if X[:, 19] <= 14500.0 else to node 467.
# 												node=464 test node: go to node 465 if X[:, 46] <= 12338.8105469 else to node 466.
# 													node=465 leaf node.
# 													node=466 leaf node.
# 												node=467 leaf node.
# 											node=468 test node: go to node 469 if X[:, 49] <= 17970.9257813 else to node 472.
# 												node=469 test node: go to node 470 if X[:, 10] <= 19575.0 else to node 471.
# 													node=470 leaf node.
# 													node=471 leaf node.
# 												node=472 leaf node.
# 								node=473 test node: go to node 474 if X[:, 18] <= 735857.0 else to node 501.
# 									node=474 test node: go to node 475 if X[:, 47] <= 1968.7199707 else to node 486.
# 										node=475 test node: go to node 476 if X[:, 3] <= 2115.5 else to node 485.
# 											node=476 test node: go to node 477 if X[:, 17] <= 419.234985352 else to node 484.
# 												node=477 test node: go to node 478 if X[:, 3] <= 1703.5 else to node 483.
# 													node=478 test node: go to node 479 if X[:, 6] <= 0.5 else to node 482.
# 														node=479 test node: go to node 480 if X[:, 8] <= 726224.5 else to node 481.
# 															node=480 leaf node.
# 															node=481 leaf node.
# 														node=482 leaf node.
# 													node=483 leaf node.
# 												node=484 leaf node.
# 											node=485 leaf node.
# 										node=486 test node: go to node 487 if X[:, 49] <= 7987.88964844 else to node 488.
# 											node=487 leaf node.
# 											node=488 test node: go to node 489 if X[:, 37] <= 4511.0 else to node 490.
# 												node=489 leaf node.
# 												node=490 test node: go to node 491 if X[:, 21] <= 5.5 else to node 498.
# 													node=491 test node: go to node 492 if X[:, 24] <= 1.5 else to node 493.
# 														node=492 leaf node.
# 														node=493 test node: go to node 494 if X[:, 49] <= 11820.0449219 else to node 497.
# 															node=494 test node: go to node 495 if X[:, 10] <= 13250.0 else to node 496.
# 																node=495 leaf node.
# 																node=496 leaf node.
# 															node=497 leaf node.
# 													node=498 test node: go to node 499 if X[:, 19] <= 17037.5 else to node 500.
# 														node=499 leaf node.
# 														node=500 leaf node.
# 									node=501 test node: go to node 502 if X[:, 20] <= 19.5 else to node 685.
# 										node=502 test node: go to node 503 if X[:, 15] <= 735096.5 else to node 594.
# 											node=503 test node: go to node 504 if X[:, 21] <= 11.5 else to node 587.
# 												node=504 test node: go to node 505 if X[:, 16] <= 735857.0 else to node 508.
# 													node=505 test node: go to node 506 if X[:, 31] <= 94.5 else to node 507.
# 														node=506 leaf node.
# 														node=507 leaf node.
# 													node=508 test node: go to node 509 if X[:, 48] <= 7.5 else to node 572.
# 														node=509 test node: go to node 510 if X[:, 38] <= 0.973500013351 else to node 567.
# 															node=510 test node: go to node 511 if X[:, 8] <= 733696.5 else to node 564.
# 																node=511 test node: go to node 512 if X[:, 21] <= 6.5 else to node 541.
# 																	node=512 test node: go to node 513 if X[:, 0] <= 11.5 else to node 538.
# 																		node=513 test node: go to node 514 if X[:, 15] <= 734943.5 else to node 515.
# 																			node=514 leaf node.
# 																			node=515 test node: go to node 516 if X[:, 18] <= 736009.5 else to node 523.
# 																				node=516 test node: go to node 517 if X[:, 47] <= 2810.16503906 else to node 518.
# 																					node=517 leaf node.
# 																					node=518 test node: go to node 519 if X[:, 2] <= 67000.0 else to node 522.
# 																						node=519 test node: go to node 520 if X[:, 16] <= 736557.0 else to node 521.
# 																							node=520 leaf node.
# 																							node=521 leaf node.
# 																						node=522 leaf node.
# 																				node=523 test node: go to node 524 if X[:, 16] <= 736009.5 else to node 527.
# 																					node=524 test node: go to node 525 if X[:, 42] <= 27.0 else to node 526.
# 																						node=525 leaf node.
# 																						node=526 leaf node.
# 																					node=527 test node: go to node 528 if X[:, 0] <= 7.5 else to node 533.
# 																						node=528 test node: go to node 529 if X[:, 49] <= 4599.28515625 else to node 532.
# 																							node=529 test node: go to node 530 if X[:, 19] <= 4712.5 else to node 531.
# 																								node=530 leaf node.
# 																								node=531 leaf node.
# 																							node=532 leaf node.
# 																						node=533 test node: go to node 534 if X[:, 1] <= 5.0 else to node 537.
# 																							node=534 test node: go to node 535 if X[:, 41] <= 224517.0 else to node 536.
# 																								node=535 leaf node.
# 																								node=536 leaf node.
# 																							node=537 leaf node.
# 																		node=538 test node: go to node 539 if X[:, 17] <= 748.015014648 else to node 540.
# 																			node=539 leaf node.
# 																			node=540 leaf node.
# 																	node=541 test node: go to node 542 if X[:, 35] <= 12.5 else to node 561.
# 																		node=542 test node: go to node 543 if X[:, 38] <= 0.138500005007 else to node 546.
# 																			node=543 test node: go to node 544 if X[:, 50] <= 96300.0 else to node 545.
# 																				node=544 leaf node.
# 																				node=545 leaf node.
# 																			node=546 test node: go to node 547 if X[:, 22] <= 8.5 else to node 556.
# 																				node=547 test node: go to node 548 if X[:, 8] <= 732478.0 else to node 553.
# 																					node=548 test node: go to node 549 if X[:, 18] <= 735948.5 else to node 552.
# 																						node=549 test node: go to node 550 if X[:, 15] <= 734974.0 else to node 551.
# 																							node=550 leaf node.
# 																							node=551 leaf node.
# 																						node=552 leaf node.
# 																					node=553 test node: go to node 554 if X[:, 32] <= 12.5 else to node 555.
# 																						node=554 leaf node.
# 																						node=555 leaf node.
# 																				node=556 test node: go to node 557 if X[:, 7] <= 29.8050003052 else to node 558.
# 																					node=557 leaf node.
# 																					node=558 test node: go to node 559 if X[:, 7] <= 29.8999996185 else to node 560.
# 																						node=559 leaf node.
# 																						node=560 leaf node.
# 																		node=561 test node: go to node 562 if X[:, 22] <= 10.0 else to node 563.
# 																			node=562 leaf node.
# 																			node=563 leaf node.
# 																node=564 test node: go to node 565 if X[:, 9] <= 0.5 else to node 566.
# 																	node=565 leaf node.
# 																	node=566 leaf node.
# 															node=567 test node: go to node 568 if X[:, 41] <= 8300.0 else to node 569.
# 																node=568 leaf node.
# 																node=569 test node: go to node 570 if X[:, 38] <= 0.974500000477 else to node 571.
# 																	node=570 leaf node.
# 																	node=571 leaf node.
# 														node=572 test node: go to node 573 if X[:, 29] <= 6.0 else to node 586.
# 															node=573 test node: go to node 574 if X[:, 6] <= 5.5 else to node 583.
# 																node=574 test node: go to node 575 if X[:, 38] <= 0.149000003934 else to node 578.
# 																	node=575 test node: go to node 576 if X[:, 15] <= 734989.0 else to node 577.
# 																		node=576 leaf node.
# 																		node=577 leaf node.
# 																	node=578 test node: go to node 579 if X[:, 18] <= 735887.5 else to node 582.
# 																		node=579 test node: go to node 580 if X[:, 48] <= 33.9099998474 else to node 581.
# 																			node=580 leaf node.
# 																			node=581 leaf node.
# 																		node=582 leaf node.
# 																node=583 test node: go to node 584 if X[:, 14] <= 0.152999997139 else to node 585.
# 																	node=584 leaf node.
# 																	node=585 leaf node.
# 															node=586 leaf node.
# 												node=587 test node: go to node 588 if X[:, 8] <= 731260.5 else to node 593.
# 													node=588 test node: go to node 589 if X[:, 14] <= 0.189500004053 else to node 590.
# 														node=589 leaf node.
# 														node=590 test node: go to node 591 if X[:, 59] <= 0.5 else to node 592.
# 															node=591 leaf node.
# 															node=592 leaf node.
# 													node=593 leaf node.
# 											node=594 test node: go to node 595 if X[:, 18] <= 736161.5 else to node 642.
# 												node=595 test node: go to node 596 if X[:, 17] <= 636.809997559 else to node 629.
# 													node=596 test node: go to node 597 if X[:, 17] <= 204.554992676 else to node 604.
# 														node=597 test node: go to node 598 if X[:, 49] <= 4385.875 else to node 603.
# 															node=598 test node: go to node 599 if X[:, 18] <= 736085.5 else to node 600.
# 																node=599 leaf node.
# 																node=600 test node: go to node 601 if X[:, 46] <= 5527.64990234 else to node 602.
# 																	node=601 leaf node.
# 																	node=602 leaf node.
# 															node=603 leaf node.
# 														node=604 test node: go to node 605 if X[:, 49] <= 13233.2050781 else to node 624.
# 															node=605 test node: go to node 606 if X[:, 13] <= 203.455001831 else to node 607.
# 																node=606 leaf node.
# 																node=607 test node: go to node 608 if X[:, 49] <= 8929.46484375 else to node 615.
# 																	node=608 test node: go to node 609 if X[:, 16] <= 736618.5 else to node 610.
# 																		node=609 leaf node.
# 																		node=610 test node: go to node 611 if X[:, 11] <= 8800.0 else to node 614.
# 																			node=611 test node: go to node 612 if X[:, 27] <= 9.0 else to node 613.
# 																				node=612 leaf node.
# 																				node=613 leaf node.
# 																			node=614 leaf node.
# 																	node=615 test node: go to node 616 if X[:, 19] <= 13650.0 else to node 623.
# 																		node=616 test node: go to node 617 if X[:, 6] <= 1.5 else to node 622.
# 																			node=617 test node: go to node 618 if X[:, 34] <= 0.5 else to node 619.
# 																				node=618 leaf node.
# 																				node=619 test node: go to node 620 if X[:, 22] <= 6.5 else to node 621.
# 																					node=620 leaf node.
# 																					node=621 leaf node.
# 																			node=622 leaf node.
# 																		node=623 leaf node.
# 															node=624 test node: go to node 625 if X[:, 7] <= 5.73000001907 else to node 626.
# 																node=625 leaf node.
# 																node=626 test node: go to node 627 if X[:, 17] <= 633.050048828 else to node 628.
# 																	node=627 leaf node.
# 																	node=628 leaf node.
# 													node=629 test node: go to node 630 if X[:, 47] <= 5893.06005859 else to node 639.
# 														node=630 test node: go to node 631 if X[:, 7] <= 32.7849998474 else to node 636.
# 															node=631 test node: go to node 632 if X[:, 24] <= 0.5 else to node 635.
# 																node=632 test node: go to node 633 if X[:, 7] <= 15.1800003052 else to node 634.
# 																	node=633 leaf node.
# 																	node=634 leaf node.
# 																node=635 leaf node.
# 															node=636 test node: go to node 637 if X[:, 21] <= 4.5 else to node 638.
# 																node=637 leaf node.
# 																node=638 leaf node.
# 														node=639 test node: go to node 640 if X[:, 49] <= 30249.4550781 else to node 641.
# 															node=640 leaf node.
# 															node=641 leaf node.
# 												node=642 test node: go to node 643 if X[:, 48] <= 93.4199981689 else to node 682.
# 													node=643 test node: go to node 644 if X[:, 41] <= 7750.0 else to node 647.
# 														node=644 test node: go to node 645 if X[:, 4] <= 46.5999984741 else to node 646.
# 															node=645 leaf node.
# 															node=646 leaf node.
# 														node=647 test node: go to node 648 if X[:, 18] <= 736192.5 else to node 657.
# 															node=648 test node: go to node 649 if X[:, 47] <= 2808.08496094 else to node 652.
# 																node=649 test node: go to node 650 if X[:, 28] <= 30.5 else to node 651.
# 																	node=650 leaf node.
# 																	node=651 leaf node.
# 																node=652 test node: go to node 653 if X[:, 38] <= 0.48449999094 else to node 654.
# 																	node=653 leaf node.
# 																	node=654 test node: go to node 655 if X[:, 41] <= 333746.0 else to node 656.
# 																		node=655 leaf node.
# 																		node=656 leaf node.
# 															node=657 test node: go to node 658 if X[:, 38] <= 0.946500003338 else to node 675.
# 																node=658 test node: go to node 659 if X[:, 8] <= 733513.0 else to node 672.
# 																	node=659 test node: go to node 660 if X[:, 52] <= 0.5 else to node 661.
# 																		node=660 leaf node.
# 																		node=661 test node: go to node 662 if X[:, 18] <= 736253.5 else to node 671.
# 																			node=662 test node: go to node 663 if X[:, 15] <= 735188.0 else to node 664.
# 																				node=663 leaf node.
# 																				node=664 test node: go to node 665 if X[:, 42] <= 16.5 else to node 668.
# 																					node=665 test node: go to node 666 if X[:, 24] <= 2.0 else to node 667.
# 																						node=666 leaf node.
# 																						node=667 leaf node.
# 																					node=668 test node: go to node 669 if X[:, 30] <= 7.5 else to node 670.
# 																						node=669 leaf node.
# 																						node=670 leaf node.
# 																			node=671 leaf node.
# 																	node=672 test node: go to node 673 if X[:, 48] <= 17.0499992371 else to node 674.
# 																		node=673 leaf node.
# 																		node=674 leaf node.
# 																node=675 test node: go to node 676 if X[:, 1] <= 47.5 else to node 681.
# 																	node=676 test node: go to node 677 if X[:, 10] <= 33000.0 else to node 680.
# 																		node=677 test node: go to node 678 if X[:, 8] <= 722023.0 else to node 679.
# 																			node=678 leaf node.
# 																			node=679 leaf node.
# 																		node=680 leaf node.
# 																	node=681 leaf node.
# 													node=682 test node: go to node 683 if X[:, 49] <= 20018.34375 else to node 684.
# 														node=683 leaf node.
# 														node=684 leaf node.
# 										node=685 leaf node.
# 						node=686 test node: go to node 687 if X[:, 18] <= 736284.0 else to node 828.
# 							node=687 test node: go to node 688 if X[:, 47] <= 1093.21496582 else to node 745.
# 								node=688 test node: go to node 689 if X[:, 49] <= 4993.44042969 else to node 712.
# 									node=689 test node: go to node 690 if X[:, 19] <= 4987.5 else to node 711.
# 										node=690 test node: go to node 691 if X[:, 41] <= 1055173.0 else to node 710.
# 											node=691 test node: go to node 692 if X[:, 47] <= 923.244995117 else to node 705.
# 												node=692 test node: go to node 693 if X[:, 35] <= 11.5 else to node 702.
# 													node=693 test node: go to node 694 if X[:, 27] <= 10.5 else to node 699.
# 														node=694 test node: go to node 695 if X[:, 44] <= 1550.0 else to node 698.
# 															node=695 test node: go to node 696 if X[:, 21] <= 2.5 else to node 697.
# 																node=696 leaf node.
# 																node=697 leaf node.
# 															node=698 leaf node.
# 														node=699 test node: go to node 700 if X[:, 50] <= 14150.0 else to node 701.
# 															node=700 leaf node.
# 															node=701 leaf node.
# 													node=702 test node: go to node 703 if X[:, 3] <= 4961.0 else to node 704.
# 														node=703 leaf node.
# 														node=704 leaf node.
# 												node=705 test node: go to node 706 if X[:, 17] <= 377.825012207 else to node 709.
# 													node=706 test node: go to node 707 if X[:, 17] <= 108.930007935 else to node 708.
# 														node=707 leaf node.
# 														node=708 leaf node.
# 													node=709 leaf node.
# 											node=710 leaf node.
# 										node=711 leaf node.
# 									node=712 test node: go to node 713 if X[:, 47] <= 876.064941406 else to node 730.
# 										node=713 test node: go to node 714 if X[:, 24] <= 39.5 else to node 727.
# 											node=714 test node: go to node 715 if X[:, 48] <= 7.5 else to node 724.
# 												node=715 test node: go to node 716 if X[:, 67] <= 0.5 else to node 717.
# 													node=716 leaf node.
# 													node=717 test node: go to node 718 if X[:, 31] <= 75.4000015259 else to node 719.
# 														node=718 leaf node.
# 														node=719 test node: go to node 720 if X[:, 10] <= 16875.0 else to node 721.
# 															node=720 leaf node.
# 															node=721 test node: go to node 722 if X[:, 19] <= 17300.0 else to node 723.
# 																node=722 leaf node.
# 																node=723 leaf node.
# 												node=724 test node: go to node 725 if X[:, 47] <= 818.130004883 else to node 726.
# 													node=725 leaf node.
# 													node=726 leaf node.
# 											node=727 test node: go to node 728 if X[:, 1] <= 30.0 else to node 729.
# 												node=728 leaf node.
# 												node=729 leaf node.
# 										node=730 test node: go to node 731 if X[:, 14] <= 0.0804499983788 else to node 736.
# 											node=731 test node: go to node 732 if X[:, 46] <= 9887.734375 else to node 735.
# 												node=732 test node: go to node 733 if X[:, 8] <= 723910.0 else to node 734.
# 													node=733 leaf node.
# 													node=734 leaf node.
# 												node=735 leaf node.
# 											node=736 test node: go to node 737 if X[:, 47] <= 1087.91503906 else to node 742.
# 												node=737 test node: go to node 738 if X[:, 18] <= 736253.5 else to node 739.
# 													node=738 leaf node.
# 													node=739 test node: go to node 740 if X[:, 47] <= 895.679992676 else to node 741.
# 														node=740 leaf node.
# 														node=741 leaf node.
# 												node=742 test node: go to node 743 if X[:, 46] <= 6415.88476563 else to node 744.
# 													node=743 leaf node.
# 													node=744 leaf node.
# 								node=745 test node: go to node 746 if X[:, 49] <= 9949.50488281 else to node 781.
# 									node=746 test node: go to node 747 if X[:, 10] <= 9937.5 else to node 780.
# 										node=747 test node: go to node 748 if X[:, 49] <= 5992.875 else to node 767.
# 											node=748 test node: go to node 749 if X[:, 17] <= 548.53503418 else to node 764.
# 												node=749 test node: go to node 750 if X[:, 19] <= 5587.5 else to node 757.
# 													node=750 test node: go to node 751 if X[:, 49] <= 3999.95507813 else to node 752.
# 														node=751 leaf node.
# 														node=752 test node: go to node 753 if X[:, 49] <= 4342.41992188 else to node 756.
# 															node=753 test node: go to node 754 if X[:, 13] <= 171.895004272 else to node 755.
# 																node=754 leaf node.
# 																node=755 leaf node.
# 															node=756 leaf node.
# 													node=757 test node: go to node 758 if X[:, 17] <= 25.0799999237 else to node 759.
# 														node=758 leaf node.
# 														node=759 test node: go to node 760 if X[:, 30] <= 27.5 else to node 761.
# 															node=760 leaf node.
# 															node=761 test node: go to node 762 if X[:, 0] <= 13.0 else to node 763.
# 																node=762 leaf node.
# 																node=763 leaf node.
# 												node=764 test node: go to node 765 if X[:, 47] <= 2086.96484375 else to node 766.
# 													node=765 leaf node.
# 													node=766 leaf node.
# ...
# 																						node=2360 leaf node.
# 																					node=2361 leaf node.
# 																				node=2362 leaf node.
# 																			node=2363 test node: go to node 2364 if X[:, 14] <= 0.186499997973 else to node 2367.
# 																				node=2364 test node: go to node 2365 if X[:, 8] <= 732600.5 else to node 2366.
# 																					node=2365 leaf node.
# 																					node=2366 leaf node.
# 																				node=2367 leaf node.
# 																		node=2368 leaf node.
# 																	node=2369 test node: go to node 2370 if X[:, 12] <= 0.5 else to node 2391.
# 																		node=2370 test node: go to node 2371 if X[:, 49] <= 3986.10009766 else to node 2374.
# 																			node=2371 test node: go to node 2372 if X[:, 44] <= 33500.0 else to node 2373.
# 																				node=2372 leaf node.
# 																				node=2373 leaf node.
# 																			node=2374 test node: go to node 2375 if X[:, 32] <= 96.6500015259 else to node 2386.
# 																				node=2375 test node: go to node 2376 if X[:, 9] <= 1.5 else to node 2385.
# 																					node=2376 test node: go to node 2377 if X[:, 0] <= 3.5 else to node 2384.
# 																						node=2377 test node: go to node 2378 if X[:, 51] <= 0.5 else to node 2383.
# 																							node=2378 test node: go to node 2379 if X[:, 1] <= 36.0 else to node 2380.
# 																								node=2379 leaf node.
# 																								node=2380 test node: go to node 2381 if X[:, 17] <= 18508.125 else to node 2382.
# 																									node=2381 leaf node.
# 																									node=2382 leaf node.
# 																							node=2383 leaf node.
# 																						node=2384 leaf node.
# 																					node=2385 leaf node.
# 																				node=2386 test node: go to node 2387 if X[:, 10] <= 22575.0 else to node 2388.
# 																					node=2387 leaf node.
# 																					node=2388 test node: go to node 2389 if X[:, 49] <= 21320.1699219 else to node 2390.
# 																						node=2389 leaf node.
# 																						node=2390 leaf node.
# 																		node=2391 test node: go to node 2392 if X[:, 15] <= 734823.0 else to node 2397.
# 																			node=2392 test node: go to node 2393 if X[:, 42] <= 61.5 else to node 2394.
# 																				node=2393 leaf node.
# 																				node=2394 test node: go to node 2395 if X[:, 40] <= 129030.0 else to node 2396.
# 																					node=2395 leaf node.
# 																					node=2396 leaf node.
# 																			node=2397 leaf node.
# 															node=2398 test node: go to node 2399 if X[:, 31] <= 72.1500015259 else to node 2402.
# 																node=2399 test node: go to node 2400 if X[:, 27] <= 4.0 else to node 2401.
# 																	node=2400 leaf node.
# 																	node=2401 leaf node.
# 																node=2402 leaf node.
# 														node=2403 test node: go to node 2404 if X[:, 49] <= 6619.93994141 else to node 2407.
# 															node=2404 test node: go to node 2405 if X[:, 17] <= 6577.51464844 else to node 2406.
# 																node=2405 leaf node.
# 																node=2406 leaf node.
# 															node=2407 leaf node.
# 													node=2408 test node: go to node 2409 if X[:, 35] <= 0.5 else to node 2410.
# 														node=2409 leaf node.
# 														node=2410 leaf node.
# 												node=2411 test node: go to node 2412 if X[:, 50] <= 220950.0 else to node 2413.
# 													node=2412 leaf node.
# 													node=2413 leaf node.
# 									node=2414 test node: go to node 2415 if X[:, 31] <= 60.5499992371 else to node 2418.
# 										node=2415 test node: go to node 2416 if X[:, 29] <= 2.5 else to node 2417.
# 											node=2416 leaf node.
# 											node=2417 leaf node.
# 										node=2418 test node: go to node 2419 if X[:, 3] <= 76002.0 else to node 2430.
# 											node=2419 test node: go to node 2420 if X[:, 0] <= 7.5 else to node 2421.
# 												node=2420 leaf node.
# 												node=2421 test node: go to node 2422 if X[:, 24] <= 0.5 else to node 2423.
# 													node=2422 leaf node.
# 													node=2423 test node: go to node 2424 if X[:, 42] <= 18.5 else to node 2429.
# 														node=2424 test node: go to node 2425 if X[:, 10] <= 10725.0 else to node 2426.
# 															node=2425 leaf node.
# 															node=2426 test node: go to node 2427 if X[:, 28] <= 7.5 else to node 2428.
# 																node=2427 leaf node.
# 																node=2428 leaf node.
# 														node=2429 leaf node.
# 											node=2430 test node: go to node 2431 if X[:, 3] <= 79112.5 else to node 2432.
# 												node=2431 leaf node.
# 												node=2432 leaf node.
# 						node=2433 test node: go to node 2434 if X[:, 49] <= 9965.11523438 else to node 2447.
# 							node=2434 test node: go to node 2435 if X[:, 11] <= 9975.0 else to node 2446.
# 								node=2435 test node: go to node 2436 if X[:, 6] <= 5.5 else to node 2445.
# 									node=2436 test node: go to node 2437 if X[:, 31] <= 65.8499984741 else to node 2440.
# 										node=2437 test node: go to node 2438 if X[:, 10] <= 6937.5 else to node 2439.
# 											node=2438 leaf node.
# 											node=2439 leaf node.
# 										node=2440 test node: go to node 2441 if X[:, 38] <= 0.0684999972582 else to node 2444.
# 											node=2441 test node: go to node 2442 if X[:, 7] <= 16.625 else to node 2443.
# 												node=2442 leaf node.
# 												node=2443 leaf node.
# 											node=2444 leaf node.
# 									node=2445 leaf node.
# 								node=2446 leaf node.
# 							node=2447 test node: go to node 2448 if X[:, 44] <= 160350.0 else to node 2489.
# 								node=2448 test node: go to node 2449 if X[:, 28] <= 28.5 else to node 2486.
# 									node=2449 test node: go to node 2450 if X[:, 16] <= 736618.5 else to node 2455.
# 										node=2450 test node: go to node 2451 if X[:, 31] <= 70.5 else to node 2454.
# 											node=2451 test node: go to node 2452 if X[:, 8] <= 732052.0 else to node 2453.
# 												node=2452 leaf node.
# 												node=2453 leaf node.
# 											node=2454 leaf node.
# 										node=2455 test node: go to node 2456 if X[:, 2] <= 45500.0 else to node 2469.
# 											node=2456 test node: go to node 2457 if X[:, 37] <= 24869.5 else to node 2468.
# 												node=2457 test node: go to node 2458 if X[:, 19] <= 17737.5 else to node 2465.
# 													node=2458 test node: go to node 2459 if X[:, 57] <= 0.5 else to node 2460.
# 														node=2459 leaf node.
# 														node=2460 test node: go to node 2461 if X[:, 22] <= 8.0 else to node 2464.
# 															node=2461 test node: go to node 2462 if X[:, 9] <= 1.5 else to node 2463.
# 																node=2462 leaf node.
# 																node=2463 leaf node.
# 															node=2464 leaf node.
# 													node=2465 test node: go to node 2466 if X[:, 11] <= 18500.0 else to node 2467.
# 														node=2466 leaf node.
# 														node=2467 leaf node.
# 												node=2468 leaf node.
# 											node=2469 test node: go to node 2470 if X[:, 4] <= 92.0999984741 else to node 2475.
# 												node=2470 test node: go to node 2471 if X[:, 10] <= 24262.5 else to node 2472.
# 													node=2471 leaf node.
# 													node=2472 test node: go to node 2473 if X[:, 55] <= 0.5 else to node 2474.
# 														node=2473 leaf node.
# 														node=2474 leaf node.
# 												node=2475 test node: go to node 2476 if X[:, 8] <= 721735.0 else to node 2477.
# 													node=2476 leaf node.
# 													node=2477 test node: go to node 2478 if X[:, 40] <= 27749.0 else to node 2481.
# 														node=2478 test node: go to node 2479 if X[:, 43] <= 23307.0 else to node 2480.
# 															node=2479 leaf node.
# 															node=2480 leaf node.
# 														node=2481 test node: go to node 2482 if X[:, 45] <= 73547.0 else to node 2483.
# 															node=2482 leaf node.
# 															node=2483 test node: go to node 2484 if X[:, 44] <= 16400.0 else to node 2485.
# 																node=2484 leaf node.
# 																node=2485 leaf node.
# 									node=2486 test node: go to node 2487 if X[:, 4] <= 37.2000007629 else to node 2488.
# 										node=2487 leaf node.
# 										node=2488 leaf node.
# 								node=2489 test node: go to node 2490 if X[:, 11] <= 18000.0 else to node 2491.
# 									node=2490 leaf node.
# 									node=2491 leaf node.
# 					node=2492 test node: go to node 2493 if X[:, 49] <= 30924.5507813 else to node 2494.
# 						node=2493 leaf node.
# 						node=2494 leaf node.
# 				node=2495 test node: go to node 2496 if X[:, 49] <= 9927.58007813 else to node 2499.
# 					node=2496 test node: go to node 2497 if X[:, 19] <= 9900.0 else to node 2498.
# 						node=2497 leaf node.
# 						node=2498 leaf node.
# 					node=2499 test node: go to node 2500 if X[:, 17] <= 2568.97509766 else to node 2527.
# 						node=2500 test node: go to node 2501 if X[:, 49] <= 19656.8164063 else to node 2506.
# 							node=2501 test node: go to node 2502 if X[:, 19] <= 18250.0 else to node 2505.
# 								node=2502 test node: go to node 2503 if X[:, 17] <= 1323.85498047 else to node 2504.
# 									node=2503 leaf node.
# 									node=2504 leaf node.
# 								node=2505 leaf node.
# 							node=2506 test node: go to node 2507 if X[:, 21] <= 8.5 else to node 2524.
# 								node=2507 test node: go to node 2508 if X[:, 17] <= 2567.66503906 else to node 2523.
# 									node=2508 test node: go to node 2509 if X[:, 4] <= 41.3499984741 else to node 2514.
# 										node=2509 test node: go to node 2510 if X[:, 4] <= 37.1999969482 else to node 2513.
# 											node=2510 test node: go to node 2511 if X[:, 39] <= 48.0 else to node 2512.
# 												node=2511 leaf node.
# 												node=2512 leaf node.
# 											node=2513 leaf node.
# 										node=2514 test node: go to node 2515 if X[:, 42] <= 54.5 else to node 2520.
# 											node=2515 test node: go to node 2516 if X[:, 17] <= 1336.26501465 else to node 2519.
# 												node=2516 test node: go to node 2517 if X[:, 19] <= 27500.0 else to node 2518.
# 													node=2517 leaf node.
# 													node=2518 leaf node.
# 												node=2519 leaf node.
# 											node=2520 test node: go to node 2521 if X[:, 30] <= 13.5 else to node 2522.
# 												node=2521 leaf node.
# 												node=2522 leaf node.
# 									node=2523 leaf node.
# 								node=2524 test node: go to node 2525 if X[:, 41] <= 111660.0 else to node 2526.
# 									node=2525 leaf node.
# 									node=2526 leaf node.
# 						node=2527 test node: go to node 2528 if X[:, 48] <= 265.725006104 else to node 2565.
# 							node=2528 test node: go to node 2529 if X[:, 0] <= 19.5 else to node 2564.
# 								node=2529 test node: go to node 2530 if X[:, 17] <= 4538.60498047 else to node 2545.
# 									node=2530 test node: go to node 2531 if X[:, 40] <= 422916.5 else to node 2542.
# 										node=2531 test node: go to node 2532 if X[:, 47] <= 17916.359375 else to node 2541.
# 											node=2532 test node: go to node 2533 if X[:, 15] <= 735978.5 else to node 2538.
# 												node=2533 test node: go to node 2534 if X[:, 7] <= 29.9249992371 else to node 2535.
# 													node=2534 leaf node.
# 													node=2535 test node: go to node 2536 if X[:, 25] <= 5.5 else to node 2537.
# 														node=2536 leaf node.
# 														node=2537 leaf node.
# 												node=2538 test node: go to node 2539 if X[:, 28] <= 13.5 else to node 2540.
# 													node=2539 leaf node.
# 													node=2540 leaf node.
# 											node=2541 leaf node.
# 										node=2542 test node: go to node 2543 if X[:, 15] <= 735492.0 else to node 2544.
# 											node=2543 leaf node.
# 											node=2544 leaf node.
# 									node=2545 test node: go to node 2546 if X[:, 2] <= 532500.0 else to node 2561.
# 										node=2546 test node: go to node 2547 if X[:, 49] <= 17724.125 else to node 2550.
# 											node=2547 test node: go to node 2548 if X[:, 11] <= 21250.0 else to node 2549.
# 												node=2548 leaf node.
# 												node=2549 leaf node.
# 											node=2550 test node: go to node 2551 if X[:, 24] <= 28.5 else to node 2558.
# 												node=2551 test node: go to node 2552 if X[:, 2] <= 248000.0 else to node 2553.
# 													node=2552 leaf node.
# 													node=2553 test node: go to node 2554 if X[:, 8] <= 731276.5 else to node 2555.
# 														node=2554 leaf node.
# 														node=2555 test node: go to node 2556 if X[:, 11] <= 34237.5 else to node 2557.
# 															node=2556 leaf node.
# 															node=2557 leaf node.
# 												node=2558 test node: go to node 2559 if X[:, 17] <= 7167.09472656 else to node 2560.
# 													node=2559 leaf node.
# 													node=2560 leaf node.
# 										node=2561 test node: go to node 2562 if X[:, 14] <= 0.193450003862 else to node 2563.
# 											node=2562 leaf node.
# 											node=2563 leaf node.
# 								node=2564 leaf node.
# 							node=2565 test node: go to node 2566 if X[:, 26] <= 16.0 else to node 2567.
# 								node=2566 leaf node.
# 								node=2567 leaf node.
# 	node=2568 leaf node.
#
# Rules used to predict sample 0:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: (0, -2)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-de54dc56b45e> in <module>()
#      47         continue
#      48
# ---> 49     if (x_test[sample_id, feature[node_id]] <= threshold[node_id]):
#      50         threshold_sign = "<="
#      51     else:
#
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\McKell\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: (0, -2)

# %%
x.columns[36]
# Out:
# 'recoveries'

# %%
x['recoveries'].head()
# Out:
# 0      0.0
# 1    122.9
# 2      0.0
# 3      0.0
# 4      0.0
# Name: recoveries, dtype: float64

# %%
x.columns[49]
# Out:
# 'total_rec_prncp'

# %%
x['total_rec_prncp']
# Out:
# 0          5000.00
# 1           456.46
# 2          2400.00
# 3         10000.00
# 4          3000.00
# 5          5000.00
# 6          7000.00
# 7          3000.00
# 8           162.02
# 9           673.48
# 10         6500.00
# 11        12000.00
# 12         1256.14
# 13         3000.00
# 14         5433.47
# 15         1000.00
# 16        10000.00
# 17         3600.00
# 18         6000.00
# 19         9200.00
# 20        20250.00
# 21        10694.96
# 22        10000.00
# 23        10000.00
# 24         1305.58
# 25        15000.00
# 26            0.00
# 27          629.05
# 28         4000.00
# 29         8500.00
#             ...
# 787876    32875.00
# 787878    15600.00
# 787879    15000.00
# 787880    18500.00
# 787881    11200.00
# 787882    27000.00
# 787883    20000.00
# 787884    14200.00
# 787885    15000.00
# 787886    10000.00
# 787887    26000.00
# 787888    22200.00
# 787889    10000.00
# 787890    15000.00
# 787891    40000.00
# 787892    24000.00
# 787893    24775.00
# 787894    35000.00
# 787896    12800.00
# 787897    36000.00
# 787899    30000.00
# 787900    25000.00
# 787901     7000.00
# 787902    16000.00
# 787903    10450.00
# 787905    17750.00
# 787906      263.22
# 787907    35000.00
# 787908     7000.00
# 787909    35000.00
# Name: total_rec_prncp, dtype: float64
